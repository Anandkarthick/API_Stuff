# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os
# Out:
# /Users/anandkarthick/Downloads/Python Notebooks/Micromasters - Data Science/Week-8-NLP-Databases

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /Users/anandkarthick/anaconda3/lib/python3.6/site-packages

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x106daaeb8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://developer.twitter.com/en/docs/trends/trends-for-location/api-reference/get-trends-place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %%
all_trends = list(twitter_api.trends.available())
    
for x in range(len(all_trends)):
    if (all_trends[x]['country'] == 'United States'):
        print(all_trends[x]['name'],'--', all_trends[x]['woeid'])
# Out:
# Albuquerque -- 2352824
# Atlanta -- 2357024
# Austin -- 2357536
# Baltimore -- 2358820
# Baton Rouge -- 2359991
# Birmingham -- 2364559
# Boston -- 2367105
# Charlotte -- 2378426
# Chicago -- 2379574
# Cincinnati -- 2380358
# Cleveland -- 2381475
# Colorado Springs -- 2383489
# Columbus -- 2383660
# Dallas-Ft. Worth -- 2388929
# Denver -- 2391279
# Detroit -- 2391585
# El Paso -- 2397816
# Fresno -- 2407517
# Greensboro -- 2414469
# Harrisburg -- 2418046
# Honolulu -- 2423945
# Houston -- 2424766
# Indianapolis -- 2427032
# Jackson -- 2428184
# Jacksonville -- 2428344
# Kansas City -- 2430683
# Las Vegas -- 2436704
# Long Beach -- 2441472
# Los Angeles -- 2442047
# Louisville -- 2442327
# Memphis -- 2449323
# Mesa -- 2449808
# Miami -- 2450022
# Milwaukee -- 2451822
# Minneapolis -- 2452078
# Nashville -- 2457170
# New Haven -- 2458410
# New Orleans -- 2458833
# New York -- 2459115
# Norfolk -- 2460389
# Oklahoma City -- 2464592
# Omaha -- 2465512
# Orlando -- 2466256
# Philadelphia -- 2471217
# Phoenix -- 2471390
# Pittsburgh -- 2473224
# Portland -- 2475687
# Providence -- 2477058
# Raleigh -- 2478307
# Richmond -- 2480894
# Sacramento -- 2486340
# St. Louis -- 2486982
# Salt Lake City -- 2487610
# San Antonio -- 2487796
# San Diego -- 2487889
# San Francisco -- 2487956
# San Jose -- 2488042
# Seattle -- 2490383
# Tallahassee -- 2503713
# Tampa -- 2503863
# Tucson -- 2508428
# Virginia Beach -- 2512636
# Washington -- 2514815
# United States -- 23424977

# %% [markdown]
# Look for the WOEID for [Massachusetts](http://www.woeidlookup.com/)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2367105   #Boston

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2018-03-13T01:54:08Z',
#   'created_at': '2018-03-13T01:53:36Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': 'Big Sean',
#     'promoted_content': None,
#     'query': '%22Big+Sean%22',
#     'tweet_volume': 160231,
#     'url': 'http://twitter.com/search?q=%22Big+Sean%22'},
#    {'name': '#LHHMIA',
#     'promoted_content': None,
#     'query': '%23LHHMIA',
#     'tweet_volume': 13435,
#     'url': 'http://twitter.com/search?q=%23LHHMIA'},
#    {'name': '#لك_من_اسمك_نصيب',
#     'promoted_content': None,
#     'query': '%23%D9%84%D9%83_%D9%85%D9%86_%D8%A7%D8%B3%D9%85%D9%83_%D9%86%D8%B5%D9%8A%D8%A8',
#     'tweet_volume': 26062,
#     'url': 'http://twitter.com/search?q=%23%D9%84%D9%83_%D9%85%D9%86_%D8%A7%D8%B3%D9%85%D9%83_%D9%86%D8%B5%D9%8A%D8%A8'},
#    {'name': '#isola',
#     'promoted_content': None,
#     'query': '%23isola',
#     'tweet_volume': 58587,
#     'url': 'http://twitter.com/search?q=%23isola'},
#    {'name': '#OOutroLadoParaiso',
#     'promoted_content': None,
#     'query': '%23OOutroLadoParaiso',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23OOutroLadoParaiso'},
#    {'name': '#ElRegresoMV',
#     'promoted_content': None,
#     'query': '%23ElRegresoMV',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ElRegresoMV'},
#    {'name': 'John Cena',
#     'promoted_content': None,
#     'query': '%22John+Cena%22',
#     'tweet_volume': 13957,
#     'url': 'http://twitter.com/search?q=%22John+Cena%22'},
#    {'name': 'Lali Esposito',
#     'promoted_content': None,
#     'query': '%22Lali+Esposito%22',
#     'tweet_volume': 17818,
#     'url': 'http://twitter.com/search?q=%22Lali+Esposito%22'},
#    {'name': 'House Intelligence Committee',
#     'promoted_content': None,
#     'query': '%22House+Intelligence+Committee%22',
#     'tweet_volume': 138565,
#     'url': 'http://twitter.com/search?q=%22House+Intelligence+Committee%22'},
#    {'name': 'Brandon Jennings',
#     'promoted_content': None,
#     'query': '%22Brandon+Jennings%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Brandon+Jennings%22'},
#    {'name': 'UNIAO NOPAU',
#     'promoted_content': None,
#     'query': '%22UNIAO+NOPAU%22',
#     'tweet_volume': 85479,
#     'url': 'http://twitter.com/search?q=%22UNIAO+NOPAU%22'},
#    {'name': 'Alex Ovechkin',
#     'promoted_content': None,
#     'query': '%22Alex+Ovechkin%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Alex+Ovechkin%22'},
#    {'name': 'Kalafina',
#     'promoted_content': None,
#     'query': 'Kalafina',
#     'tweet_volume': 25414,
#     'url': 'http://twitter.com/search?q=Kalafina'},
#    {'name': 'Qualcomm',
#     'promoted_content': None,
#     'query': 'Qualcomm',
#     'tweet_volume': 20152,
#     'url': 'http://twitter.com/search?q=Qualcomm'},
#    {'name': 'Devin Nunes',
#     'promoted_content': None,
#     'query': '%22Devin+Nunes%22',
#     'tweet_volume': 50615,
#     'url': 'http://twitter.com/search?q=%22Devin+Nunes%22'},
#    {'name': 'ESTAMOS CONTIGO WAGNER',
#     'promoted_content': None,
#     'query': '%22ESTAMOS+CONTIGO+WAGNER%22',
#     'tweet_volume': 62887,
#     'url': 'http://twitter.com/search?q=%22ESTAMOS+CONTIGO+WAGNER%22'},
#    {'name': 'Roman Reigns',
#     'promoted_content': None,
#     'query': '%22Roman+Reigns%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Roman+Reigns%22'},
#    {'name': 'Comisión de Credenciales',
#     'promoted_content': None,
#     'query': '%22Comisi%C3%B3n+de+Credenciales%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Comisi%C3%B3n+de+Credenciales%22'},
#    {'name': 'Emilia Navas',
#     'promoted_content': None,
#     'query': '%22Emilia+Navas%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Emilia+Navas%22'},
#    {'name': '#LunesIntratable',
#     'promoted_content': None,
#     'query': '%23LunesIntratable',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LunesIntratable'},
#    {'name': '#YaMeTieneHartoQue',
#     'promoted_content': None,
#     'query': '%23YaMeTieneHartoQue',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23YaMeTieneHartoQue'},
#    {'name': '#PumpRules',
#     'promoted_content': None,
#     'query': '%23PumpRules',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PumpRules'},
#    {'name': '#MaestrosDeLaCostura',
#     'promoted_content': None,
#     'query': '%23MaestrosDeLaCostura',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MaestrosDeLaCostura'},
#    {'name': '#ذكري_لاتنساها',
#     'promoted_content': None,
#     'query': '%23%D8%B0%D9%83%D8%B1%D9%8A_%D9%84%D8%A7%D8%AA%D9%86%D8%B3%D8%A7%D9%87%D8%A7',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%B0%D9%83%D8%B1%D9%8A_%D9%84%D8%A7%D8%AA%D9%86%D8%B3%D8%A7%D9%87%D8%A7'},
#    {'name': '#DíaInternacionalDeLosTuiteros',
#     'promoted_content': None,
#     'query': '%23D%C3%ADaInternacionalDeLosTuiteros',
#     'tweet_volume': 14509,
#     'url': 'http://twitter.com/search?q=%23D%C3%ADaInternacionalDeLosTuiteros'},
#    {'name': '#PlanPerdurar',
#     'promoted_content': None,
#     'query': '%23PlanPerdurar',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PlanPerdurar'},
#    {'name': '#تويتر_يفتقد',
#     'promoted_content': None,
#     'query': '%23%D8%AA%D9%88%D9%8A%D8%AA%D8%B1_%D9%8A%D9%81%D8%AA%D9%82%D8%AF',
#     'tweet_volume': 22153,
#     'url': 'http://twitter.com/search?q=%23%D8%AA%D9%88%D9%8A%D8%AA%D8%B1_%D9%8A%D9%81%D8%AA%D9%82%D8%AF'},
#    {'name': '#VoiceBlinds',
#     'promoted_content': None,
#     'query': '%23VoiceBlinds',
#     'tweet_volume': 13893,
#     'url': 'http://twitter.com/search?q=%23VoiceBlinds'},
#    {'name': '#LaVozKids4',
#     'promoted_content': None,
#     'query': '%23LaVozKids4',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LaVozKids4'},
#    {'name': '#RAWCL',
#     'promoted_content': None,
#     'query': '%23RAWCL',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23RAWCL'},
#    {'name': '#UnlikelyTimeChangeEffects',
#     'promoted_content': None,
#     'query': '%23UnlikelyTimeChangeEffects',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23UnlikelyTimeChangeEffects'},
#    {'name': '#güvenliseçim',
#     'promoted_content': None,
#     'query': '%23g%C3%BCvenlise%C3%A7im',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23g%C3%BCvenlise%C3%A7im'},
#    {'name': '#HagoPucheroCuando',
#     'promoted_content': None,
#     'query': '%23HagoPucheroCuando',
#     'tweet_volume': 30561,
#     'url': 'http://twitter.com/search?q=%23HagoPucheroCuando'},
#    {'name': '#ArenaLoL',
#     'promoted_content': None,
#     'query': '%23ArenaLoL',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ArenaLoL'},
#    {'name': '#TWD8enFOX',
#     'promoted_content': None,
#     'query': '%23TWD8enFOX',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TWD8enFOX'},
#    {'name': '#NosUnimosONosHundimos',
#     'promoted_content': None,
#     'query': '%23NosUnimosONosHundimos',
#     'tweet_volume': 16711,
#     'url': 'http://twitter.com/search?q=%23NosUnimosONosHundimos'},
#    {'name': '#このタグ見た人は2文字で自己紹介する',
#     'promoted_content': None,
#     'query': '%23%E3%81%93%E3%81%AE%E3%82%BF%E3%82%B0%E8%A6%8B%E3%81%9F%E4%BA%BA%E3%81%AF2%E6%96%87%E5%AD%97%E3%81%A7%E8%87%AA%E5%B7%B1%E7%B4%B9%E4%BB%8B%E3%81%99%E3%82%8B',
#     'tweet_volume': 13063,
#     'url': 'http://twitter.com/search?q=%23%E3%81%93%E3%81%AE%E3%82%BF%E3%82%B0%E8%A6%8B%E3%81%9F%E4%BA%BA%E3%81%AF2%E6%96%87%E5%AD%97%E3%81%A7%E8%87%AA%E5%B7%B1%E7%B4%B9%E4%BB%8B%E3%81%99%E3%82%8B'},
#    {'name': '#DIVIDEDSTATES',
#     'promoted_content': None,
#     'query': '%23DIVIDEDSTATES',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23DIVIDEDSTATES'},
#    {'name': '#1ConsejoParaSerSexy',
#     'promoted_content': None,
#     'query': '%231ConsejoParaSerSexy',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%231ConsejoParaSerSexy'},
#    {'name': '#LateNightBerlin',
#     'promoted_content': None,
#     'query': '%23LateNightBerlin',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LateNightBerlin'},
#    {'name': '#PapoDeSegundaNoGNT',
#     'promoted_content': None,
#     'query': '%23PapoDeSegundaNoGNT',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PapoDeSegundaNoGNT'},
#    {'name': '#inners',
#     'promoted_content': None,
#     'query': '%23inners',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23inners'},
#    {'name': '#قطر_تحتفل_بوصول_البقر',
#     'promoted_content': None,
#     'query': '%23%D9%82%D8%B7%D8%B1_%D8%AA%D8%AD%D8%AA%D9%81%D9%84_%D8%A8%D9%88%D8%B5%D9%88%D9%84_%D8%A7%D9%84%D8%A8%D9%82%D8%B1',
#     'tweet_volume': 28905,
#     'url': 'http://twitter.com/search?q=%23%D9%82%D8%B7%D8%B1_%D8%AA%D8%AD%D8%AA%D9%81%D9%84_%D8%A8%D9%88%D8%B5%D9%88%D9%84_%D8%A7%D9%84%D8%A8%D9%82%D8%B1'},
#    {'name': '#conquis9',
#     'promoted_content': None,
#     'query': '%23conquis9',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23conquis9'},
#    {'name': '#TeenMomOG',
#     'promoted_content': None,
#     'query': '%23TeenMomOG',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TeenMomOG'},
#    {'name': '#1MuyMalaMezclaEs',
#     'promoted_content': None,
#     'query': '%231MuyMalaMezclaEs',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%231MuyMalaMezclaEs'},
#    {'name': '#NoCapitulation',
#     'promoted_content': None,
#     'query': '%23NoCapitulation',
#     'tweet_volume': 10658,
#     'url': 'http://twitter.com/search?q=%23NoCapitulation'},
#    {'name': '#HawkersxJuanpaZurita',
#     'promoted_content': None,
#     'query': '%23HawkersxJuanpaZurita',
#     'tweet_volume': 10174,
#     'url': 'http://twitter.com/search?q=%23HawkersxJuanpaZurita'},
#    {'name': '#HannibalLectorsTakeOutOrder',
#     'promoted_content': None,
#     'query': '%23HannibalLectorsTakeOutOrder',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HannibalLectorsTakeOutOrder'},
#    {'name': '#JogoSagrado',
#     'promoted_content': None,
#     'query': '%23JogoSagrado',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23JogoSagrado'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#MAsnow', 'url': 'http://twitter.com/search?q=%23MAsnow', 'promoted_content': None, 'query': '%23MAsnow', 'tweet_volume': None}, {'name': '#NationalNappingDay', 'url': 'http://twitter.com/search?q=%23NationalNappingDay', 'promoted_content': None, 'query': '%23NationalNappingDay', 'tweet_volume': 135203}, {'name': 'Tom Brady', 'url': 'http://twitter.com/search?q=%22Tom+Brady%22', 'promoted_content': None, 'query': '%22Tom+Brady%22', 'tweet_volume': 18053}, {'name': '#MondayMotivation', 'url': 'http://twitter.com/search?q=%23MondayMotivation', 'promoted_content': None, 'query': '%23MondayMotivation', 'tweet_volume': 258604}, {'name': 'New England', 'url': 'http://twitter.com/search?q=%22New+England%22', 'promoted_content': None, 'query': '%22New+England%22', 'tweet_volume': None}, {'name': 'Brad Stevens', 'url': 'http://twitter.com/search?q=%22Brad+Stevens%22', 'promoted_content': None, 'query': '%22Brad+Stevens%22', 'tweet_volume': None}, {'name': 'Daniel Theis', 'url': 'http://twitter.com/search?q=%22Daniel+Theis%22', 'promoted_content': None, 'query': '%22Daniel+Theis%22', 'tweet_volume': None}, {'name': 'Betsy DeVos', 'url': 'http://twitter.com/search?q=%22Betsy+DeVos%22', 'promoted_content': None, 'query': '%22Betsy+DeVos%22', 'tweet_volume': 290844}, {'name': 'Big Sean', 'url': 'http://twitter.com/search?q=%22Big+Sean%22', 'promoted_content': None, 'query': '%22Big+Sean%22', 'tweet_volume': 193756}, {'name': '#LHHMIA', 'url': 'http://twitter.com/search?q=%23LHHMIA', 'promoted_content': None, 'query': '%23LHHMIA', 'tweet_volume': 15444}, {'name': '#PumpRules', 'url': 'http://twitter.com/search?q=%23PumpRules', 'promoted_content': None, 'query': '%23PumpRules', 'tweet_volume': None}, {'name': 'House Intelligence Committee', 'url': 'http://twitter.com/search?q=%22House+Intelligence+Committee%22', 'promoted_content': None, 'query': '%22House+Intelligence+Committee%22', 'tweet_volume': 152128}, {'name': 'Brandon Jennings', 'url': 'http://twitter.com/search?q=%22Brandon+Jennings%22', 'promoted_content': None, 'query': '%22Brandon+Jennings%22', 'tweet_volume': None}, {'name': 'John Cena', 'url': 'http://twitter.com/search?q=%22John+Cena%22', 'promoted_content': None, 'query': '%22John+Cena%22', 'tweet_volume': 12864}, {'name': 'Devin Nunes', 'url': 'http://twitter.com/search?q=%22Devin+Nunes%22', 'promoted_content': None, 'query': '%22Devin+Nunes%22', 'tweet_volume': 54451}, {'name': 'Moolah', 'url': 'http://twitter.com/search?q=Moolah', 'promoted_content': None, 'query': 'Moolah', 'tweet_volume': None}, {'name': 'Roman', 'url': 'http://twitter.com/search?q=Roman', 'promoted_content': None, 'query': 'Roman', 'tweet_volume': 48330}, {'name': 'Alex Ovechkin', 'url': 'http://twitter.com/search?q=%22Alex+Ovechkin%22', 'promoted_content': None, 'query': '%22Alex+Ovechkin%22', 'tweet_volume': None}, {'name': 'Qualcomm', 'url': 'http://twitter.com/search?q=Qualcomm', 'promoted_content': None, 'query': 'Qualcomm', 'tweet_volume': 20691}, {'name': 'WNIT', 'url': 'http://twitter.com/search?q=WNIT', 'promoted_content': None, 'query': 'WNIT', 'tweet_volume': None}, {'name': 'Nicole Scherzinger', 'url': 'http://twitter.com/search?q=%22Nicole+Scherzinger%22', 'promoted_content': None, 'query': '%22Nicole+Scherzinger%22', 'tweet_volume': None}, {'name': 'Marc-Andre Fleury', 'url': 'http://twitter.com/search?q=%22Marc-Andre+Fleury%22', 'promoted_content': None, 'query': '%22Marc-Andre+Fleury%22', 'tweet_volume': None}, {'name': 'Finn Balor', 'url': 'http://twitter.com/search?q=%22Finn+Balor%22', 'promoted_content': None, 'query': '%22Finn+Balor%22', 'tweet_volume': None}, {'name': 'The Bar', 'url': 'http://twitter.com/search?q=%22The+Bar%22', 'promoted_content': None, 'query': '%22The+Bar%22', 'tweet_volume': 17484}, {'name': 'Pretty Ricky', 'url': 'http://twitter.com/search?q=%22Pretty+Ricky%22', 'promoted_content': None, 'query': '%22Pretty+Ricky%22', 'tweet_volume': None}, {'name': 'Wayne Simmonds', 'url': 'http://twitter.com/searc ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(world_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "Big Sean",
#     "url": "http://twitter.com/search?q=%22Big+Sean%22",
#     "promoted_content": null,
#     "query": "%22Big+Sean%22",
#     "tweet_volume": 160231
#    },
#    {
#     "name": "#LHHMIA",
#     "url": "http://twitter.com/search?q=%23LHHMIA",
#     "promoted_content": null,
#     "query": "%23LHHMIA",
#     "tweet_volume": 13435
#    },
#    {
#     "name": "#\u0644\u0643_\u0645\u0646_\u0627\u0633\u0645\u0643_\u0646\u0635\u064a\u0628",
#     "url": "http://twitter.com/search?q=%23%D9%84%D9%83_%D9%85%D9%86_%D8%A7%D8%B3%D9%85%D9%83_%D9%86%D8%B5%D9%8A%D8%A8",
#     "promoted_content": null,
#     "query": "%23%D9%84%D9%83_%D9%85%D9%86_%D8%A7%D8%B3%D9%85%D9%83_%D9%86%D8%B5%D9%8A%D8%A8",
#     "tweet_volume": 26062
#    },
#    {
#     "name": "#isola",
#     "url": "http://twitter.com/search?q=%23isola",
#     "promoted_content": null,
#     "query": "%23isola",
#     "tweet_volume": 58587
#    },
#    {
#     "name": "#OOutroLadoParaiso",
#     "url": "http://twitter.com/search?q=%23OOutroLadoParaiso",
#     "promoted_content": null,
#     "query": "%23OOutroLadoParaiso",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ElRegresoMV",
#     "url": "http://twitter.com/search?q=%23ElRegresoMV",
#     "promoted_content": null,
#     "query": "%23ElRegresoMV",
#     "tweet_volume": null
#    },
#    {
#     "name": "John Cena",
#     "url": "http://twitter.com/search?q=%22John+Cena%22",
#     "promoted_content": null,
#     "query": "%22John+Cena%22",
#     "tweet_volume": 13957
#    },
#    {
#     "name": "Lali Esposito",
#     "url": "http://twitter.com/search?q=%22Lali+Esposito%22",
#     "promoted_content": null,
#     "query": "%22Lali+Esposito%22",
#     "tweet_volume": 17818
#    },
#    {
#     "name": "House Intelligence Committee",
#     "url": "http://twitter.com/search?q=%22House+Intelligence+Committee%22",
#     "promoted_content": null,
#     "query": "%22House+Intelligence+Committee%22",
#     "tweet_volume": 138565
#    },
#    {
#     "name": "Brandon Jennings",
#     "url": "http://twitter.com/search?q=%22Brandon+Jennings%22",
#     "promoted_content": null,
#     "query": "%22Brandon+Jennings%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "UNIAO NOPAU",
#     "url": "http://twitter.com/search?q=%22UNIAO+NOPAU%22",
#     "promoted_content": null,
#     "query": "%22UNIAO+NOPAU%22",
#     "tweet_volume": 85479
#    },
#    {
#     "name": "Alex Ovechkin",
#     "url": "http://twitter.com/search?q=%22Alex+Ovechkin%22",
#     "promoted_content": null,
#     "query": "%22Alex+Ovechkin%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kalafina",
#     "url": "http://twitter.com/search?q=Kalafina",
#     "promoted_content": null,
#     "query": "Kalafina",
#     "tweet_volume": 25414
#    },
#    {
#     "name": "Qualcomm",
#     "url": "http://twitter.com/search?q=Qualcomm",
#     "promoted_content": null,
#     "query": "Qualcomm",
#     "tweet_volume": 20152
#    },
#    {
#     "name": "Devin Nunes",
#     "url": "http://twitter.com/search?q=%22Devin+Nunes%22",
#     "promoted_content": null,
#     "query": "%22Devin+Nunes%22",
#     "tweet_volume": 50615
#    },
#    {
#     "name": "ESTAMOS CONTIGO WAGNER",
#     "url": "http://twitter.com/search?q=%22ESTAMOS+CONTIGO+WAGNER%22",
#     "promoted_content": null,
#     "query": "%22ESTAMOS+CONTIGO+WAGNER%22",
#     "tweet_volume": 62887
#    },
#    {
#     "name": "Roman Reigns",
#     "url": "http://twitter.com/search?q=%22Roman+Reigns%22",
#     "promoted_content": null,
#     "query": "%22Roman+Reigns%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Comisi\u00f3n de Credenciales",
#     "url": "http://twitter.com/search?q=%22Comisi%C3%B3n+de+Credenciales%22",
#     "promoted_content": null,
#     "query": "%22Comisi%C3%B3n+de+Credenciales%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Emilia Navas",
#     "url": "http://twitter.com/search?q=%22Emilia+Navas%22",
#     "promoted_content": null,
#     "query": "%22Emilia+Navas%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LunesIntratable",
#     "url": "http://twitter.com/search?q=%23LunesIntratable",
#     "promoted_content": null,
#     "query": "%23LunesIntratable",
#     "tweet_volume": null
#    },
#    {
#     "name": "#YaMeTieneHartoQue",
#     "url": "http://twitter.com/search?q=%23YaMeTieneHartoQue",
#     "promoted_content": null,
#     "query": "%23YaMeTieneHartoQue",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PumpRules",
#     "url": "http://twitter.com/search?q=%23PumpRules",
#     "promoted_content": null,
#     "query": "%23PumpRules",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MaestrosDeLaCostura",
#     "url": "http://twitter.com/search?q=%23MaestrosDeLaCostura",
#     "promoted_content": null,
#     "query": "%23MaestrosDeLaCostura",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0630\u0643\u0631\u064a_\u0644\u0627\u062a\u0646\u0633\u0627\u0647\u0627",
#     "url": "http://twitter.com/search?q=%23%D8%B0%D9%83%D8%B1%D9%8A_%D9%84%D8%A7%D8%AA%D9%86%D8%B3%D8%A7%D9%87%D8%A7",
#     "promoted_content": null,
#     "query": "%23%D8%B0%D9%83%D8%B1%D9%8A_%D9%84%D8%A7%D8%AA%D9%86%D8%B3%D8%A7%D9%87%D8%A7",
#     "tweet_volume": null
#    },
#    {
#     "name": "#D\u00edaInternacionalDeLosTuiteros",
#     "url": "http://twitter.com/search?q=%23D%C3%ADaInternacionalDeLosTuiteros",
#     "promoted_content": null,
#     "query": "%23D%C3%ADaInternacionalDeLosTuiteros",
#     "tweet_volume": 14509
#    },
#    {
#     "name": "#PlanPerdurar",
#     "url": "http://twitter.com/search?q=%23PlanPerdurar",
#     "promoted_content": null,
#     "query": "%23PlanPerdurar",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u062a\u0648\u064a\u062a\u0631_\u064a\u0641\u062a\u0642\u062f",
#     "url": "http://twitter.com/search?q=%23%D8%AA%D9%88%D9%8A%D8%AA%D8%B1_%D9%8A%D9%81%D8%AA%D9%82%D8%AF",
#     "promoted_content": null,
#     "query": "%23%D8%AA%D9%88%D9%8A%D8%AA%D8%B1_%D9%8A%D9%81%D8%AA%D9%82%D8%AF",
#     "tweet_volume": 22153
#    },
#    {
#     "name": "#VoiceBlinds",
#     "url": "http://twitter.com/search?q=%23VoiceBlinds",
#     "promoted_content": null,
#     "query": "%23VoiceBlinds",
#     "tweet_volume": 13893
#    },
#    {
#     "name": "#LaVozKids4",
#     "url": "http://twitter.com/search?q=%23LaVozKids4",
#     "promoted_content": null,
#     "query": "%23LaVozKids4",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RAWCL",
#     "url": "http://twitter.com/search?q=%23RAWCL",
#     "promoted_content": null,
#     "query": "%23RAWCL",
#     "tweet_volume": null
#    },
#    {
#     "name": "#UnlikelyTimeChangeEffects",
#     "url": "http://twitter.com/search?q=%23UnlikelyTimeChangeEffects",
#     "promoted_content": null,
#     "query": "%23UnlikelyTimeChangeEffects",
#     "tweet_volume": null
#    },
#    {
#     "name": "#g\u00fcvenlise\u00e7im",
#     "url": "http://twitter.com/search?q=%23g%C3%BCvenlise%C3%A7im",
#     "promoted_content": null,
#     "query": "%23g%C3%BCvenlise%C3%A7im",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HagoPucheroCuando",
#     "url": "http://twitter.com/search?q=%23HagoPucheroCuando",
#     "promoted_content": null,
#     "query": "%23HagoPucheroCuando",
#     "tweet_volume": 30561
#    },
#    {
#     "name": "#ArenaLoL",
#     "url": "http://twitter.com/search?q=%23ArenaLoL",
#     "promoted_content": null,
#     "query": "%23ArenaLoL",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TWD8enFOX",
#     "url": "http://twitter.com/search?q=%23TWD8enFOX",
#     "promoted_content": null,
#     "query": "%23TWD8enFOX",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NosUnimosONosHundimos",
#     "url": "http://twitter.com/search?q=%23NosUnimosONosHundimos",
#     "promoted_content": null,
#     "query": "%23NosUnimosONosHundimos",
#     "tweet_volume": 16711
#    },
#    {
#     "name": "#\u3053\u306e\u30bf\u30b0\u898b\u305f\u4eba\u306f2\u6587\u5b57\u3067\u81ea\u5df1\u7d39\u4ecb\u3059\u308b",
#     "url": "http://twitter.com/search?q=%23%E3%81%93%E3%81%AE%E3%82%BF%E3%82%B0%E8%A6%8B%E3%81%9F%E4%BA%BA%E3%81%AF2%E6%96%87%E5%AD%97%E3%81%A7%E8%87%AA%E5%B7%B1%E7%B4%B9%E4%BB%8B%E3%81%99%E3%82%8B",
#     "promoted_content": null,
#     "query": "%23%E3%81%93%E3%81%AE%E3%82%BF%E3%82%B0%E8%A6%8B%E3%81%9F%E4%BA%BA%E3%81%AF2%E6%96%87%E5%AD%97%E3%81%A7%E8%87%AA%E5%B7%B1%E7%B4%B9%E4%BB%8B%E3%81%99%E3%82%8B",
#     "tweet_volume": 13063
#    },
#    {
#     "name": "#DIVIDEDSTATES",
#     "url": "http://twitter.com/search?q=%23DIVIDEDSTATES",
#     "promoted_content": null,
#     "query": "%23DIVIDEDSTATES",
#     "tweet_volume": null
#    },
#    {
#     "name": "#1ConsejoParaSerSexy",
#     "url": "http://twitter.com/search?q=%231ConsejoParaSerSexy",
#     "promoted_content": null,
#     "query": "%231ConsejoParaSerSexy",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LateNightBerlin",
#     "url": "http://twitter.com/search?q=%23LateNightBerlin",
#     "promoted_content": null,
#     "query": "%23LateNightBerlin",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PapoDeSegundaNoGNT",
#     "url": "http://twitter.com/search?q=%23PapoDeSegundaNoGNT",
#     "promoted_content": null,
#     "query": "%23PapoDeSegundaNoGNT",
#     "tweet_volume": null
#    },
#    {
#     "name": "#inners",
#     "url": "http://twitter.com/search?q=%23inners",
#     "promoted_content": null,
#     "query": "%23inners",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0642\u0637\u0631_\u062a\u062d\u062a\u0641\u0644_\u0628\u0648\u0635\u0648\u0644_\u0627\u0644\u0628\u0642\u0631",
#     "url": "http://twitter.com/search?q=%23%D9%82%D8%B7%D8%B1_%D8%AA%D8%AD%D8%AA%D9%81%D9%84_%D8%A8%D9%88%D8%B5%D9%88%D9%84_%D8%A7%D9%84%D8%A8%D9%82%D8%B1",
#     "promoted_content": null,
#     "query": "%23%D9%82%D8%B7%D8%B1_%D8%AA%D8%AD%D8%AA%D9%81%D9%84_%D8%A8%D9%88%D8%B5%D9%88%D9%84_%D8%A7%D9%84%D8%A8%D9%82%D8%B1",
#     "tweet_volume": 28905
#    },
#    {
#     "name": "#conquis9",
#     "url": "http://twitter.com/search?q=%23conquis9",
#     "promoted_content": null,
#     "query": "%23conquis9",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TeenMomOG",
#     "url": "http://twitter.com/search?q=%23TeenMomOG",
#     "promoted_content": null,
#     "query": "%23TeenMomOG",
#     "tweet_volume": null
#    },
#    {
#     "name": "#1MuyMalaMezclaEs",
#     "url": "http://twitter.com/search?q=%231MuyMalaMezclaEs",
#     "promoted_content": null,
#     "query": "%231MuyMalaMezclaEs",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NoCapitulation",
#     "url": "http://twitter.com/search?q=%23NoCapitulation",
#     "promoted_content": null,
#     "query": "%23NoCapitulation",
#     "tweet_volume": 10658
#    },
#    {
#     "name": "#HawkersxJuanpaZurita",
#     "url": "http://twitter.com/search?q=%23HawkersxJuanpaZurita",
#     "promoted_content": null,
#     "query": "%23HawkersxJuanpaZurita",
#     "tweet_volume": 10174
#    },
#    {
#     "name": "#HannibalLectorsTakeOutOrder",
#     "url": "http://twitter.com/search?q=%23HannibalLectorsTakeOutOrder",
#     "promoted_content": null,
#     "query": "%23HannibalLectorsTakeOutOrder",
#     "tweet_volume": null
#    },
#    {
#     "name": "#JogoSagrado",
#     "url": "http://twitter.com/search?q=%23JogoSagrado",
#     "promoted_content": null,
#     "query": "%23JogoSagrado",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-03-13T02:02:18Z",
#   "created_at": "2018-03-13T01:53:36Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends
# Out:
# [{'as_of': '2018-03-13T02:02:19Z',
#   'created_at': '2018-03-13T01:58:31Z',
#   'locations': [{'name': 'San Diego', 'woeid': 2487889}],
#   'trends': [{'name': '#NationalNappingDay',
#     'promoted_content': None,
#     'query': '%23NationalNappingDay',
#     'tweet_volume': 134606,
#     'url': 'http://twitter.com/search?q=%23NationalNappingDay'},
#    {'name': '#MondayMotivation',
#     'promoted_content': None,
#     'query': '%23MondayMotivation',
#     'tweet_volume': 259172,
#     'url': 'http://twitter.com/search?q=%23MondayMotivation'},
#    {'name': 'NCAA Tournament',
#     'promoted_content': None,
#     'query': '%22NCAA+Tournament%22',
#     'tweet_volume': 55248,
#     'url': 'http://twitter.com/search?q=%22NCAA+Tournament%22'},
#    {'name': '#DaylightSavings',
#     'promoted_content': None,
#     'query': '%23DaylightSavings',
#     'tweet_volume': 19962,
#     'url': 'http://twitter.com/search?q=%23DaylightSavings'},
#    {'name': '#BREAKING',
#     'promoted_content': None,
#     'query': '%23BREAKING',
#     'tweet_volume': 47594,
#     'url': 'http://twitter.com/search?q=%23BREAKING'},
#    {'name': 'Betsy DeVos',
#     'promoted_content': None,
#     'query': '%22Betsy+DeVos%22',
#     'tweet_volume': 303048,
#     'url': 'http://twitter.com/search?q=%22Betsy+DeVos%22'},
#    {'name': '#Trump',
#     'promoted_content': None,
#     'query': '%23Trump',
#     'tweet_volume': 84311,
#     'url': 'http://twitter.com/search?q=%23Trump'},
#    {'name': 'Big Sean',
#     'promoted_content': None,
#     'query': '%22Big+Sean%22',
#     'tweet_volume': 171666,
#     'url': 'http://twitter.com/search?q=%22Big+Sean%22'},
#    {'name': 'Brandon Jennings',
#     'promoted_content': None,
#     'query': '%22Brandon+Jennings%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Brandon+Jennings%22'},
#    {'name': 'John Cena',
#     'promoted_content': None,
#     'query': '%22John+Cena%22',
#     'tweet_volume': 14135,
#     'url': 'http://twitter.com/search?q=%22John+Cena%22'},
#    {'name': 'Devin Nunes',
#     'promoted_content': None,
#     'query': '%22Devin+Nunes%22',
#     'tweet_volume': 52081,
#     'url': 'http://twitter.com/search?q=%22Devin+Nunes%22'},
#    {'name': 'House Republicans',
#     'promoted_content': None,
#     'query': '%22House+Republicans%22',
#     'tweet_volume': 37515,
#     'url': 'http://twitter.com/search?q=%22House+Republicans%22'},
#    {'name': 'Moolah',
#     'promoted_content': None,
#     'query': 'Moolah',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Moolah'},
#    {'name': 'Roman',
#     'promoted_content': None,
#     'query': 'Roman',
#     'tweet_volume': 49683,
#     'url': 'http://twitter.com/search?q=Roman'},
#    {'name': 'WNIT',
#     'promoted_content': None,
#     'query': 'WNIT',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=WNIT'},
#    {'name': 'Nicole Scherzinger',
#     'promoted_content': None,
#     'query': '%22Nicole+Scherzinger%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Nicole+Scherzinger%22'},
#    {'name': 'Finn Balor',
#     'promoted_content': None,
#     'query': '%22Finn+Balor%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Finn+Balor%22'},
#    {'name': 'Marc-Andre Fleury',
#     'promoted_content': None,
#     'query': '%22Marc-Andre+Fleury%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Marc-Andre+Fleury%22'},
#    {'name': 'The Bar',
#     'promoted_content': None,
#     'query': '%22The+Bar%22',
#     'tweet_volume': 18631,
#     'url': 'http://twitter.com/search?q=%22The+Bar%22'},
#    {'name': 'Pretty Ricky',
#     'promoted_content': None,
#     'query': '%22Pretty+Ricky%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Pretty+Ricky%22'},
#    {'name': 'Wayne Simmonds',
#     'promoted_content': None,
#     'query': '%22Wayne+Simmonds%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Wayne+Simmonds%22'},
#    {'name': 'Reigns',
#     'promoted_content': None,
#     'query': 'Reigns',
#     'tweet_volume': 12259,
#     'url': 'http://twitter.com/search?q=Reigns'},
#    {'name': 'Ian Cole',
#     'promoted_content': None,
#     'query': '%22Ian+Cole%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Ian+Cole%22'},
#    {'name': 'Jimmy Vesey',
#     'promoted_content': None,
#     'query': '%22Jimmy+Vesey%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Jimmy+Vesey%22'},
#    {'name': 'Seth Jones',
#     'promoted_content': None,
#     'query': '%22Seth+Jones%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Seth+Jones%22'},
#    {'name': 'Mrazek',
#     'promoted_content': None,
#     'query': 'Mrazek',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Mrazek'},
#    {'name': 'Thaddeus',
#     'promoted_content': None,
#     'query': 'Thaddeus',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Thaddeus'},
#    {'name': 'Little Fires Everywhere',
#     'promoted_content': None,
#     'query': '%22Little+Fires+Everywhere%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Little+Fires+Everywhere%22'},
#    {'name': '#MarchMadness',
#     'promoted_content': None,
#     'query': '%23MarchMadness',
#     'tweet_volume': 47722,
#     'url': 'http://twitter.com/search?q=%23MarchMadness'},
#    {'name': '#SXSW',
#     'promoted_content': None,
#     'query': '%23SXSW',
#     'tweet_volume': 62711,
#     'url': 'http://twitter.com/search?q=%23SXSW'},
#    {'name': '#LHHMIA',
#     'promoted_content': None,
#     'query': '%23LHHMIA',
#     'tweet_volume': 14366,
#     'url': 'http://twitter.com/search?q=%23LHHMIA'},
#    {'name': '#PumpRules',
#     'promoted_content': None,
#     'query': '%23PumpRules',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PumpRules'},
#    {'name': '#VoiceBlinds',
#     'promoted_content': None,
#     'query': '%23VoiceBlinds',
#     'tweet_volume': 14865,
#     'url': 'http://twitter.com/search?q=%23VoiceBlinds'},
#    {'name': '#UnlikelyTimeChangeEffects',
#     'promoted_content': None,
#     'query': '%23UnlikelyTimeChangeEffects',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23UnlikelyTimeChangeEffects'},
#    {'name': '#DIVIDEDSTATES',
#     'promoted_content': None,
#     'query': '%23DIVIDEDSTATES',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23DIVIDEDSTATES'},
#    {'name': '#inners',
#     'promoted_content': None,
#     'query': '%23inners',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23inners'},
#    {'name': '#TeenMomOG',
#     'promoted_content': None,
#     'query': '%23TeenMomOG',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TeenMomOG'},
#    {'name': '#Lucifer',
#     'promoted_content': None,
#     'query': '%23Lucifer',
#     'tweet_volume': 10231,
#     'url': 'http://twitter.com/search?q=%23Lucifer'},
#    {'name': '#HannibalLectorsTakeOutOrder',
#     'promoted_content': None,
#     'query': '%23HannibalLectorsTakeOutOrder',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HannibalLectorsTakeOutOrder'},
#    {'name': '#TheResident',
#     'promoted_content': None,
#     'query': '%23TheResident',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TheResident'},
#    {'name': '#RawCast',
#     'promoted_content': None,
#     'query': '%23RawCast',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23RawCast'},
#    {'name': '#600VI',
#     'promoted_content': None,
#     'query': '%23600VI',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23600VI'},
#    {'name': '#COMC2018',
#     'promoted_content': None,
#     'query': '%23COMC2018',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23COMC2018'},
#    {'name': '#FireSomeonePolitely',
#     'promoted_content': None,
#     'query': '%23FireSomeonePolitely',
#     'tweet_volume': 11075,
#     'url': 'http://twitter.com/search?q=%23FireSomeonePolitely'},
#    {'name': '#Hannity',
#     'promoted_content': None,
#     'query': '%23Hannity',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Hannity'},
#    {'name': '#SpringBakingChampionship',
#     'promoted_content': None,
#     'query': '%23SpringBakingChampionship',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SpringBakingChampionship'},
#    {'name': '#HGTVHomeTown',
#     'promoted_content': None,
#     'query': '%23HGTVHomeTown',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HGTVHomeTown'},
#    {'name': '#hogfbchat',
#     'promoted_content': None,
#     'query': '%23hogfbchat',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23hogfbchat'},
#    {'name': '#amysbabies',
#     'promoted_content': None,
#     'query': '%23amysbabies',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23amysbabies'},
#    {'name': '#ChicagoTonight',
#     'promoted_content': None,
#     'query': '%23ChicagoTonight',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ChicagoTonight'}]}]

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['boston'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','boston']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #LaVozKids4,#لك_من_اسمك_نصيب,ESTAMOS CONTIGO WAGNER,#1ConsejoParaSerSexy,#UnlikelyTimeChangeEffects,#TWD8enFOX,Kalafina,#conquis9,#inners,#LunesIntratable,John Cena,#NoCapitulation,Roman Reigns,#OOutroLadoParaiso,#PapoDeSegundaNoGNT,#قطر_تحتفل_بوصول_البقر,Comisión de Credenciales,UNIAO NOPAU,House Intelligence Committee,#تويتر_يفتقد,#ArenaLoL,#このタグ見た人は2文字で自己紹介する,#HagoPucheroCuando,#JogoSagrado,#güvenliseçim,#TeenMomOG,#1MuyMalaMezclaEs,#DíaInternacionalDeLosTuiteros,Qualcomm,#ElRegresoMV,#RAWCL,#LHHMIA,Brandon Jennings,Alex Ovechkin,#HawkersxJuanpaZurita,#LateNightBerlin,#YaMeTieneHartoQue,#ذكري_لاتنساها,#HannibalLectorsTakeOutOrder,Devin Nunes,#isola,Big Sean,#DIVIDEDSTATES,Lali Esposito,#PumpRules,#MaestrosDeLaCostura,#PlanPerdurar,#NosUnimosONosHundimos,#VoiceBlinds,Emilia Navas
# ('----------', 'us')
# #ChicagoTonight,#CapsJets,WNIT,#UnlikelyTimeChangeEffects,#FireSomeonePolitely,Nicole Scherzinger,House Republicans,Nolan Patrick,#inners,John Cena,#Lucifer,#HGTVHomeTown,Pretty Ricky,Roman,Seth Jones,House Intelligence Committee,Mrazek,Trump and Russia,#TeenMomOG,Wayne Simmonds,Qualcomm,Marc-Andre Fleury,#SelectionMonday,#SpringBakingChampionship,Ian Cole,#LHHMIA,Finn Balor,Brandon Jennings,The Bar,Little Fires Everywhere,Alex Ovechkin,Thaddeus,#COMC2018,Reigns,Moolah,#HannibalLectorsTakeOutOrder,#amysbabies,Devin Nunes,Vesey,#RawCast,Big Sean,#hogfbchat,#TheResident,#PumpRules,#VoiceBlinds
# ('----------', 'boston')
# #TheAlienist,#HannibalLectersTakeOutOrder,WNIT,#UnlikelyTimeChangeEffects,#FireSomeonePolitely,Nicole Scherzinger,#iZombie,#inners,John Cena,#Lucifer,#HGTVHomeTown,Pretty Ricky,Roman,New England,Taylor Fritz,Seth Jones,House Intelligence Committee,#Hannity,Trump and Russia,Brad Stevens,Daniel Theis,#TeenMomOG,Wayne Simmonds,Qualcomm,Marc-Andre Fleury,#SpringBakingChampionship,Ian Cole,#LHHMIA,Finn Balor,Brandon Jennings,The Bar,#COMC2018,Alex Ovechkin,#600VI,Moolah,#TheGoodDoctor,Betsy DeVos,Devin Nunes,Vesey,#RawCast,Big Sean,#DIVIDEDSTATES,#MAsnow,#hogfbchat,#TheResident,#PumpRules,Tom Brady,#MondayMotivation,#NationalNappingDay,#VoiceBlinds

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and boston'))
print((trends_set['boston'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#HannibalLectorsTakeOutOrder', '#inners', 'John Cena', 'Devin Nunes', '#TeenMomOG', 'Big Sean', 'Qualcomm', '#PumpRules', '#LHHMIA', '#UnlikelyTimeChangeEffects', 'Brandon Jennings', 'Alex Ovechkin', 'House Intelligence Committee', '#VoiceBlinds'}
# ('==========', 'intersection of us and boston')
# {'WNIT', '#UnlikelyTimeChangeEffects', '#FireSomeonePolitely', 'Nicole Scherzinger', '#inners', 'John Cena', '#Lucifer', '#HGTVHomeTown', 'Pretty Ricky', 'Roman', 'Seth Jones', 'House Intelligence Committee', 'Trump and Russia', '#TeenMomOG', 'Wayne Simmonds', 'Qualcomm', 'Marc-Andre Fleury', '#SpringBakingChampionship', 'Ian Cole', '#LHHMIA', 'Finn Balor', 'Brandon Jennings', 'The Bar', '#COMC2018', 'Alex Ovechkin', 'Moolah', 'Devin Nunes', 'Vesey', '#RawCast', 'Big Sean', '#hogfbchat', '#TheResident', '#PumpRules', '#VoiceBlinds'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = 'Qualcomm' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Tue Mar 13 02:36:31 +0000 2018', 'id': 973387299240202240, 'id_str': '973387299240202240', 'text': 'RT @GartrellLinda: VIDEO: Trump Executive Order blocks Broadcom’s $117B bid for Qualcomm \nGovernment sees National Security Risk if deal wa…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'GartrellLinda', 'name': 'Deplorable Linda G.', 'id': 3518486666, 'id_str': '3518486666', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 768809753304793088, 'id_str': '768809753304793088', 'name': '🌪SAVEtheCHILDREN🌪', 'screen_name': 'MissLanley', 'location': 'Not From Russia, not a bot', 'description': 'spreadin awareness of Child #SexTrafficking & #SexRituals in our #government & #Hollywood #Trump #MAGA #TheStorm #humanRights #modernslavery🌪👧🏻\U0001f9d2🏼👶🏽🇺🇸', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3844, 'friends_count': 4714, 'listed_count': 9, 'created_at': 'Thu Aug 25 13:58:23 +0000 2016', 'favourites_count': 6955, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 7807, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/973287498540552197/l0YG2BKt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973287498540552197/l0YG2BKt_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/768809753304793088/1514755338', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Mar 12 23:54:13 +0000 2018', 'id': 973346455078436865, 'id_str': '973346455078436865', 'text': 'VIDEO: Trump Executive Order blocks Broadcom’s $117B bid for Qualcomm \nGovernment sees National Security Risk if de… https://t.co/DeN1sIXWEb', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/DeN1sIXWEb', 'expanded_url': 'https://twitter.com/i/web/status/973346455078436865', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3518486666, 'id_str': '3518486666', 'name': 'Deplorable Linda G.', 'screen_name': 'GartrellLinda', 'location': 'United States', 'description': 'Evangelical Christian Conservative Former teacher & business owner. Came on twitter just to follow President Trump. #MAGA  #trump2020 #Potus   NO PORN or SALES', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 89449, 'friends_count': 51829, 'listed_count': 218, 'created_at': 'Thu Sep 10 19:06:16 +0000 2015', 'favourites_count': 119303, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 157807, 'lang': 'en', 'contribu ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 84

# %%
s
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 13 02:32:54 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 364810202,
#     'id_str': '364810202',
#     'indices': [3, 18],
#     'name': 'News_Executive',
#     'screen_name': 'News_Executive'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 973386388254199809,
#  'id_str': '973386388254199809',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 25,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 12 22:37:46 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/973327214400999425',
#      'indices': [117, 140],
#      'url': 'https://t.co/xfX8pwlMLQ'}],
#    'user_mentions': []},
#   'favorite_count': 24,
#   'favorited': False,
#   'geo': None,
#   'id': 973327214400999425,
#   'id_str': '973327214400999425',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 25,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'BREAKING: U.S President Trump has issued an order blocking Singapore-based chipmaker Broadcom from buying U.S. riva… https://t.co/xfX8pwlMLQ',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Aug 30 11:28:47 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Journalist bringing you real time news from around the world. Always trying my best to bring you the most reliable & accurate exclusive news.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1594,
#    'follow_request_sent': False,
#    'followers_count': 27667,
#    'following': False,
#    'friends_count': 908,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 364810202,
#    'id_str': '364810202',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 876,
#    'location': 'Wherever the news happens',
#    'name': 'News_Executive',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/364810202/1445808948',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/658395589332344833/WouZCJuu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/658395589332344833/WouZCJuu_normal.jpg',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'News_Executive',
#    'statuses_count': 17778,
#    'time_zone': 'London',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 0,
#    'verified': False}},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#  'text': 'RT @News_Executive: BREAKING: U.S President Trump has issued an order blocking Singapore-based chipmaker Broadcom from buying U.S. rival Qu…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Thu Dec 15 00:19:19 +0000 2011',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': "New's, Information & Opinion / Interactive On Surging Global #ElectricFueledVehicle, #RenewableEnergy, #EnergyStorage, #Sustainability, #AI & #IoT Industry's",
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 193011,
#   'follow_request_sent': False,
#   'followers_count': 4124,
#   'following': False,
#   'friends_count': 4998,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 437085205,
#   'id_str': '437085205',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 1386,
#   'location': '',
#   'name': 'Thomas J. Thias / Clean Energy Retort',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/382277220/Copy_of_1st_Volt_Sale-2011.jpg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/382277220/Copy_of_1st_Volt_Sale-2011.jpg',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/437085205/1399391471',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1708625808/Motor_City_Volt_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1708625808/Motor_City_Volt_normal.jpg',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'AmazingChevVolt',
#   'statuses_count': 249492,
#   'time_zone': 'Eastern Time (US & Canada)',
#   'translator_type': 'regular',
#   'url': None,
#   'utc_offset': -14400,
#   'verified': False}}

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @GartrellLinda: VIDEO: Trump Executive Order blocks Broadcom’s $117B bid for Qualcomm \nGovernment sees National Security Risk if deal wa…',
#  'RT @japantimes: Trump squelches $121 billion Broadcom hostile takeover of Qualcomm, cites national security  https://t.co/uFUDuLC1LE',
#  'RT @STcom: Trump signs order prohibiting Broadcom takeover of Qualcomm https://t.co/praJpT6a0R https://t.co/3Uw2V33Sk8',
#  'RT @GartrellLinda: VIDEO: Trump Executive Order blocks Broadcom’s $117B bid for Qualcomm \nGovernment sees National Security Risk if deal wa
$117B bid for Qualcomm \nGovernment sees National Security Risk if deal wa\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "GartrellLinda",
#     "name": "Deplorable Linda G.",
#     "id": 3518486666,
#     "id_str": "3518486666",
#     "indices": [
#      3,
#      17
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 768809753304793088,
#   "id_str": "768809753304793088",
#   "name": "\ud83c\udf2aSAVEtheCHILDREN\ud83c\udf2a",
#   "screen_name": "MissLanley",
#   "location": "Not From Russia, not a bot",
#   "description": "spreadin awareness of Child #SexTrafficking & #SexRituals in our #government & #Hollywood #Trump #MAGA #TheStorm #humanRights #modernslavery\ud83c\udf2a\ud83d\udc67\ud83c\udffb\ud83e\uddd2\ud83c\udffc\ud83d\udc76\ud83c\udffd\ud83c\uddfa\ud83c\uddf8",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 3844,
#   "friends_count": 4714,
#   "listed_count": 9,
#   "created_at": "Thu Aug 25 13:58:23 +0000 2016",
#   "favourites_count": 6955,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 7807,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/973287498540552197/l0YG2BKt_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/973287498540552197/l0YG2BKt_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/768809753304793088/1514755338",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Mon Mar 12 23:54:13 +0000 2018",
#   "id": 973346455078436865,
#   "id_str": "973346455078436865",
#   "text": "VIDEO: Trump Executive Order blocks Broadcom\u2019s $117B bid for Qualcomm \nGovernment sees National Security Risk if de\u2026 https://t.co/DeN1sIXWEb",
#   "truncated": true,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/DeN1sIXWEb",
#      "expanded_url": "https://twitter.com/i/web/status/973346455078436865",
#      "display_url": "twitter.com/i/web/status/9\u2026",
#      "indices": [
#       117,
#       140
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 3518486666,
#    "id_str": "3518486666",
#    "name": "Deplorable Linda G.",
#    "screen_name": "GartrellLinda",
#    "location": "United States",
#    "description": "Evangelical Christian Conservative Former teacher & business owner. Came on twitter just to follow President Trump. #MAGA  #trump2020 #Potus   NO PORN or SALES",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 89449,
#    "friends_count": 51829,
#    "listed_count": 218,
#    "created_at": "Thu Sep 10 19:06:16 +0000 2015",
#    "favourites_count": 119303,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 157807,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/948259209774235650/11FRwIQp_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/948259209774235650/11FRwIQp_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/3518486666/1469417179",
#    "profile_link_color": "E81C4F",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": false,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 236,
#   "favorite_count": 296,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 236,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 236
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @GartrellLinda: VIDEO: Trump Executive Order blocks Broadcom\u2019s $117B bid for Qualcomm \nGovernment sees National Security Risk if deal wa\u2026",
#  "RT @japantimes: Trump squelches $121 billion Broadcom hostile takeover of Qualcomm, cites national security  https://t.co/uFUDuLC1LE",
#  "RT @STcom: Trump signs order prohibiting Broadcom takeover of Qualcomm https://t.co/praJpT6a0R https://t.co/3Uw2V33Sk8",
#  "RT @dcexaminer: Trump blocks $117 billion takeover of telecom supplier Qualcomm https://t.co/mnJZm5Rc9c https://t.co/d6ShtijeIK",
#  "RT @AP: BRAKING: President Trump blocks Singapore-based Broadcom's takeover of U.S. chipmaker Qualcomm on national security grounds."
# ]
# [
#  "GartrellLinda",
#  "japantimes",
#  "STcom",
#  "dcexaminer",
#  "AP"
# ]
# [
#  "ad",
#  "tech",
#  "jmc4410",
#  "BreakingNews",
#  "tictocnews"
# ]
# [
#  "RT",
#  "@GartrellLinda:",
#  "VIDEO:",
#  "Trump",
#  "Executive"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('Trump', 52), ('Qualcomm', 46), ('RT', 33), ('Broadcom', 29), ('of', 28), ('to', 22), ('blocks', 17), ('takeover', 17), ('bid', 15), ('for', 15)]
#
# [('AP', 2), ('realDonaldTrump', 2), ('POTUS', 2), ('Broadcom', 2), ('Qualcomm', 2), ('GartrellLinda', 1), ('japantimes', 1), ('STcom', 1), ('dcexaminer', 1), ('mp13456789', 1)]
#
# [('Qualcomm', 3), ('tictocnews', 2), ('QAnon', 2), ('MAGA', 2), ('Broadcom', 2), ('川普', 2), ('ad', 1), ('tech', 1), ('jmc4410', 1), ('BreakingNews', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# Trump                |     52
# Qualcomm             |     46
# RT                   |     33
# Broadcom             |     29
# of                   |     28
# to                   |     22
# blocks               |     17
# takeover             |     17
# bid                  |     15
# for                  |     15
#
#     Screen Name      | Count
# ****************************************
# AP                   |      2
# realDonaldTrump      |      2
# POTUS                |      2
# Broadcom             |      2
# Qualcomm             |      2
# GartrellLinda        |      1
# japantimes           |      1
# STcom                |      1
# dcexaminer           |      1
# mp13456789           |      1
#
#       Hashtag        | Count
# ****************************************
# Qualcomm             |      3
# tictocnews           |      2
# QAnon                |      2
# MAGA                 |      2
# Broadcom             |      2
# 川普                   |      2
# ad                   |      1
# tech                 |      1
# jmc4410              |      1
# BreakingNews         |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#   871   |       AP        | RT @AP: BRAKING: President Trump blocks Singapore-
#         |                 | based Broadcom's takeover of U.S. chipmaker Qualco
#         |                 | mm on national security grounds.
#   459   |  IngrahamAngle  | RT @IngrahamAngle: MORE GOOD NEWS!  Trump blocks B
#         |                 | roadcom-Qualcomm deal over China concerns https://
#         |                 | t.co/t0W2WFgTxG @realdonaldtrump
#   236   |  GartrellLinda  | RT @GartrellLinda: VIDEO: Trump Executive Order bl
#         |                 | ocks Broadcom’s $117B bid for Qualcomm \Government
#         |                 |  sees National Security Risk if deal wa…
#   173   |   mp13456789    | RT @mp13456789: Make “your phone” YOUR PHONE. Expl
#         |                 | ore the benefits of Universal Unlocked Smartphones
#         |                 |  @BestBuy https://t.co/LlP16PFBai #ad @…
#   130   |   FoxBusiness   | RT @FoxBusiness: #BreakingNews: Trump blocks Broad
#         |                 | com’s $117B bid for Qualcomm https://t.co/Y2RNGnpH
#         |                 | X9 https://t.co/cYqnMVlpoT
#   84    |  brother_chui   | RT @brother_chui: #川普 下令禁止🚫Broadcom 收购Qualcomm!\Br
#         |                 | oadcom是新加坡的公司，但是华为是他的客户。\\#川普 说：只要涉及中国公司，无论是直接还是间接
#         |                 | ，一律禁止🚫！ https://t.co/DAtMbfuwKW
#   67    |  itmedia_news   | RT @itmedia_news: トランプ大統領、BroadcomによるQualcomm買収を禁止
#         |                 | する命令\https://t.co/9JFbaf2DKy https://t.co/qH4NrOH4
#         |                 | Jv
#   46    | Trey_VonDinkis  | RT @Trey_VonDinkis: #MAGA #Mergers #Data #5G\\.🚫 S
#         |                 | eeing a Threat to National Security, Trump Blocks
#         |                 | Blocks Broadcom from Acquiring Qualcomm…
#   42    |    dekdarion    | RT @dekdarion: Citing a "national security threat"
#         |                 |  🤔 #QAnon\\https://t.co/g9wFn1FLSa
#   42    |       WSJ       | RT @WSJ: Trump orders Broadcom to cease attempt to
#         |                 |  buy Qualcomm\https://t.co/BBUZh7goq3 https://t.co
#         |                 | /LmyIazNGP3
